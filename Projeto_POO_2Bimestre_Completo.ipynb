# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:**
#
# **Turma:**
#
# **Tema Escolhido:**

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
class Emilly_viagensplanejadas:
    def __init__(self, destino, data, status):
        self.destino = destino
        self.data = data
        self.status = status

    def exibir_dados_Emilly(self):
        return f"Destino: {self.destino}, Data: {self.data}, Status: {self.status}"

viagem1 = Emilly_viagensplanejadas("Brasil", "2025-06-10", "Planejada")
viagem2 = Emilly_viagensplanejadas("Argentina", "2025-07-15", "Confirmada")

print(viagem1.exibir_dados_Emilly())
print(viagem2.exibir_dados_Emilly())

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
class Emilly_viagensplanejadas:
    def __init__(self, destino, data, status):
        self.destino = destino
        self.data = data
        self.status = status

    def exibir_dados_Emilly(self):
        return f"Destino: {self.destino}, Data: {self.data}, Status: {self.status}"

    def confirmar_viagem_Emilly(self):
        self.status = "Confirmada"

    def cancelar_viagem_Emilly(self):
        self.status = "Cancelada"

class ViagemPremium_Emilly(Emilly_viagensplanejadas):
    def __init__(self, destino, data, status, servico_extra):
        super().__init__(destino, data, status)
        self.servico_extra = servico_extra

    def exibir_servico_Emilly(self):
        return f"Serviço extra: {self.servico_extra}"

viagem1 = ViagemPremium_Emilly("Itália", "2025-08-20", "Planejada", "Traslado VIP")
viagem1.confirmar_viagem_Emilly()

print(viagem1.exibir_dados_Emilly())
print(viagem1.exibir_servico_Emilly())

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
class Emilly_viagensplanejadas:
    def __init__(self, destino, data, status):
        self.__destino = destino
        self.data = data
        self.status = status

    def get_destino_Emilly(self):
        return self.__destino

    def set_destino_Emilly(self, novo_destino):
        if isinstance(novo_destino, str) and novo_destino.strip() != "":
            self.__destino = novo_destino

    def exibir_dados_Emilly(self):
        return f"Destino: {self.__destino}, Data: {self.data}, Status: {self.status}"

    def viagem_confirmada_Emilly(self):
        return self.status.lower() == "confirmada"


viagem1 = Emilly_viagensplanejadas("Brasil", "2025-07-10", "Planejada")
viagem1.set_destino_Emilly("Argentina")

print(viagem1.get_destino_Emilly())
print(viagem1.exibir_dados_Emilly())
print(viagem1.viagem_confirmada_Emilly())

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
import mysql.connector

class Viagem_Emilly:
    def __init__(self, destino, data, status):
        self.destino = destino
        self.data = data
        self.status = status

    def exibir_dados_Emilly(self):
        return f"Destino: {self.destino}, Data: {self.data}, Status: {self.status}"

class ViagemEspecial_Emilly(Viagem_Emilly):
    def __init__(self, destino, data, status, guia):
        super().__init__(destino, data, status)
        self.guia = guia

    def exibir_dados_Emilly(self):
        return f"Destino: {self.destino}, Data: {self.data}, Status: {self.status}, Guia: {self.guia}"

class BancoDados_Emilly:
    def __init__(self, host='localhost', database='emilly_viagensplanejadas', user='root', password=''):
        try:
            self.conn = mysql.connector.connect(
                host=host,
                database=database,
                user=user,
                password=password
            )
            if self.conn.is_connected():
                self.cursor = self.conn.cursor()

                self.cursor.execute('''
                    CREATE TABLE IF NOT EXISTS viagens (
                        id INT AUTO_INCREMENT PRIMARY KEY,
                        destino VARCHAR(255),
                        data DATE,
                        status VARCHAR(50)
                    )
                ''')
                self.conn.commit()
                print("Conectado ao banco e tabela criada/verificada.")
        except Error as e:
            print(f"Erro ao conectar no banco de dados: {e}")

    def inserir_viagem_Emilly(self, viagem):
        sql = "INSERT INTO viagens (destino, data, status) VALUES (%s, %s, %s)"
        val = (viagem.destino, viagem.data, viagem.status)
        self.cursor.execute(sql, val)
        self.conn.commit()

    def consultar_viagens_Emilly(self):
        self.cursor.execute('SELECT * FROM viagens')
        return self.cursor.fetchall()

    def deletar_viagem_Emilly(self, id_viagem):
        sql = "DELETE FROM viagens WHERE id = %s"
        self.cursor.execute(sql, (id_viagem,))
        self.conn.commit()

    def fechar_Emilly(self):
        if self.conn.is_connected():
            self.cursor.close()
            self.conn.close()
            print("Conexão com o banco encerrada.")


db = BancoDados_Emilly(
    host='localhost',
    database='emilly_viagensplanejadas',
    user='root',
    password=''  
)
v1 = Viagem_Emilly("Brasil", "2025-07-10", "Planejada")
v2 = ViagemEspecial_Emilly("Argentina", "2025-08-15", "Confirmada", "Guia Emilly")

db.inserir_viagem_Emilly(v1)
db.inserir_viagem_Emilly(v2)

viagens = db.consultar_viagens_Emilly()
for viagem in viagens:
    print(f"ID: {viagem[0]}, Destino: {viagem[1]}, Data: {viagem[2]}, Status: {viagem[3]}")

db.deletar_viagem_Emilly(1) 

db.fechar_Emilly()

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
import mysql.connector

class Viagem_Fabio:
    def __init__(self, destino, data, status):
        self.destino = destino
        self.data = data
        self.status = status

    def exibir_dados_Fabio(self):
        return f"Destino: {self.destino}, Data: {self.data}, Status: {self.status}"

class ViagemEspecial_Fabio(Viagem_Fabio):
    def __init__(self, destino, data, status, guia):
        super().__init__(destino, data, status)
        self.guia = guia

    def exibir_dados_Fabio(self):
        return f"Destino: {self.destino}, Data: {self.data}, Status: {self.status}, Guia: {self.guia}"

class BancoDados_Fabio:
    def __init__(self, host='localhost', database='seu_banco', user='root', password=''):
        try:
            self.conn = mysql.connector.connect(
                host=host,
                database=database,
                user=user,
                password=password
            )
            self.cursor = self.conn.cursor()
            self.cursor.execute('''
                CREATE TABLE IF NOT EXISTS viagens (
                    id INT AUTO_INCREMENT PRIMARY KEY,
                    destino VARCHAR(255),
                    data DATE,
                    status VARCHAR(50)
                )
            ''')
            self.conn.commit()
        except Error as e:
            print(f"Erro ao conectar no banco: {e}")

    def inserir_viagem_Fabio(self, viagem):
        sql = "INSERT INTO viagens (destino, data, status) VALUES (%s, %s, %s)"
        val = (viagem.destino, viagem.data, viagem.status)
        self.cursor.execute(sql, val)
        self.conn.commit()

    def consultar_viagens_Fabio(self):
        self.cursor.execute('SELECT * FROM viagens')
        return self.cursor.fetchall()

    def deletar_viagem_Fabio(self, id_viagem):
        sql = "DELETE FROM viagens WHERE id = %s"
        self.cursor.execute(sql, (id_viagem,))
        self.conn.commit()

    def fechar_Fabio(self):
        if self.conn.is_connected():
            self.cursor.close()
            self.conn.close()

def menu_Fabio():
    db = BancoDados_Fabio(host='localhost', database='seu_banco', user='root', password='sua_senha')

    while True:
        print("\n===== Menu GoDream Fabio =====")
        print("1 - Cadastrar viagem")
        print("2 - Listar viagens")
        print("3 - Deletar viagem")
        print("4 - Sair")
        opcao = input("Escolha uma opção: ")

        if opcao == '1':
            destino = input("Destino: ")
            data = input("Data (AAAA-MM-DD): ")
            status = input("Status (Planejada/Confirmada): ")
            tipo = input("Tipo (normal/especial): ").strip().lower()

            if tipo == 'especial':
                guia = input("Nome do guia: ")
                viagem = ViagemEspecial_Fabio(destino, data, status, guia)
                print("Viagem especial criada:")
                print(viagem.exibir_dados_Fabio())
            else:
                viagem = Viagem_Fabio(destino, data, status)
                print("Viagem criada:")
                print(viagem.exibir_dados_Fabio())

            db.inserir_viagem_Fabio(viagem)

        elif opcao == '2':
            viagens = db.consultar_viagens_Fabio()
            if viagens:
                for v in viagens:
                    print(f"ID: {v[0]}, Destino: {v[1]}, Data: {v[2]}, Status: {v[3]}")
            else:
                print("Nenhuma viagem cadastrada.")

        elif opcao == '3':
            try:
                id_del = int(input("Digite o ID da viagem para deletar: "))
                db.deletar_viagem_Fabio(id_del)
                print("Viagem deletada com sucesso.")
            except ValueError:
                print("ID inválido.")

        elif opcao == '4':
            db.fechar_Fabio()
            print("Saindo... Até logo!")
            break

        else:
            print("Opção inválida, tente novamente.")
