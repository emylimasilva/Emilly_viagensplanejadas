# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:**
#
# **Turma:**
#
# **Tema Escolhido:**

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
class Viagem:
    def __init__(self, destino, data, status):
        self.destino = destino
        self.data = data
        self.status = status

    def exibir_detalhes(self):
        print(f"Destino: {self.destino}")
        print(f"Data: {self.data}")
        print(f"Status: {self.status}")
        print("-" * 30)

viagem1 = Viagem("Japão", "2025-08-15", "planejada")
viagem2 = Viagem("França", "2025-12-01", "confirmada")

viagem1.exibir_detalhes()
viagem2.exibir_detalhes()

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
class Viagem:
    def __init__(self, destino, data, status):
        self.destino = destino
        self.data = data
        self.status = status

    def alterar_status(self, novo_status):
        self.status = novo_status

    def reagendar(self, nova_data):
        self.data = nova_data

    def exibir_detalhes(self):
        print(f"Destino: {self.destino}")
        print(f"Data: {self.data}")
        print(f"Status: {self.status}")
        print("-" * 30)

class ViagemInternacional(Viagem):
    def __init__(self, destino, data, status):
        super().__init__(destino, data, status)


viagem3 = ViagemInternacional("Canadá", "2025-09-10", "planejada")
viagem3.exibir_detalhes()

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
class Viagem:
    def __init__(self, destino, data, status):
        self.__destino = destino  
        self.data = data
        self.status = status

    def get_destino(self):
        return self.__destino

    def set_destino(self, novo_destino):
        if novo_destino:  
            self.__destino = novo_destino

    def verificar_status(self):
        if self.status == "confirmada":
            return "Tudo pronto para a viagem!"
        else:
            return "Aguardando confirmação."

    def exibir_detalhes(self):
        print(f"Destino: {self.__destino}")
        print(f"Data: {self.data}")
        print(f"Status: {self.status}")
        print("-" * 30)


viagem4 = Viagem("México", "2025-07-20", "planejada")
viagem4.exibir_detalhes()
print(viagem4.verificar_status())
viagem4.set_destino("Chile")
print(viagem4.get_destino())

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
pip install mysql-connector-python

# %%
import mysql.connector

class Viagem:
    def __init__(self, destino, data, status):
        self.destino = destino
        self.data = data
        self.status = status

    def exibir_detalhes(self):
        print(f"Destino: {self.destino}")
        print(f"Data: {self.data}")
        print(f"Status: {self.status}")
        print("-" * 30)

class BancoDadosEmilly:
    def __init__(self, host='localhost', database='godream', user='root', password=''):
        self.conn = mysql.connector.connect(
            host=host,
            database=database,
            user=user,
            password=password
        )
        self.cursor = self.conn.cursor()

    def inserir_viagem(self, viagem):
        sql = "INSERT INTO viagens (destino, data, status) VALUES (%s, %s, %s)"
        val = (viagem.destino, viagem.data, viagem.status)
        self.cursor.execute(sql, val)
        self.conn.commit()

    def consultar_viagens(self):
        self.cursor.execute("SELECT * FROM viagens")
        return self.cursor.fetchall()

    def deletar_viagem(self, id_viagem):
        sql = "DELETE FROM viagens WHERE id = %s"
        self.cursor.execute(sql, (id_viagem,))
        self.conn.commit()

    def fechar(self):
        self.cursor.close()
        self.conn.close()

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
pip install mysql-connector-python

# %%
import mysql.connector

class Viagem:
    def __init__(self, destino, data, status):
        self.destino = destino
        self.data = data
        self.status = status

    def exibir_detalhes(self):
        print(f"Destino: {self.destino}")
        print(f"Data: {self.data}")
        print(f"Status: {self.status}")
        print("-" * 30)

class BancoDadosEmilly:
    def __init__(self, host='localhost', database='godream', user='root', password=''):
        self.conn = mysql.connector.connect(
            host=host,
            database=database,
            user=user,
            password=password
        )
        self.cursor = self.conn.cursor()

    def inserir_viagem(self, viagem):
        sql = "INSERT INTO viagens (destino, data, status) VALUES (%s, %s, %s)"
        val = (viagem.destino, viagem.data, viagem.status)
        self.cursor.execute(sql, val)
        self.conn.commit()

    def consultar_viagens(self):
        self.cursor.execute("SELECT id, destino, data, status FROM viagens")
        return self.cursor.fetchall()

    def deletar_viagem(self, id_viagem):
        sql = "DELETE FROM viagens WHERE id = %s"
        self.cursor.execute(sql, (id_viagem,))
        self.conn.commit()

    def fechar(self):
        self.cursor.close()
        self.conn.close()

def menu():
    db = BancoDadosEmilly()

    while True:
        print("\n--- Menu Viagens ---")
        print("1. Inserir viagem")
        print("2. Consultar todas as viagens")
        print("3. Deletar viagem por ID")
        print("4. Sair")

        escolha = input("Escolha uma opção: ")

        if escolha == '1':
            destino = input("Destino: ")
            data = input("Data (AAAA-MM-DD): ")
            status = input("Status: ")
            viagem = Viagem(destino, data, status)
            db.inserir_viagem(viagem)
            print("Viagem inserida!")

        elif escolha == '2':
            viagens = db.consultar_viagens()
            if viagens:
                for v in viagens:
                    print(f"ID: {v[0]}, Destino: {v[1]}, Data: {v[2]}, Status: {v[3]}")
            else:
                print("Nenhuma viagem cadastrada.")

        elif escolha == '3':
            id_del = input("Digite o ID da viagem para deletar: ")
            db.deletar_viagem(id_del)
            print("Viagem deletada (se o ID existir).")

        elif escolha == '4':
            print("Encerrando...")
            db.fechar()
            break

        else:
            print("Opção inválida. Tente novamente.")

menu()
